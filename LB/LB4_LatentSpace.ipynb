# %% [markdown]
# # Projecting data on PC1 and PC2 -- Latent Space and RQA

# %%
from sklearn.metrics import pairwise_distances
from tslearn.metrics import dtw
from scipy.spatial.distance import cdist

import pandas as pd

from src.config import OUT_PATH
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
def recurrence_plot(ts, eps=0.1, tau = 1, m=1):
    N = len(ts) - (m - 1) * tau # take each time point but can extend to windows 
    Y = np.array([ts[i:i + m * tau:tau] for i in range(N)])

    #N = len(ts)
    #D = np.abs(ts.reshape(N,1) - ts.reshape(1,N)) #L1 (Manhattan) distance
    D = pairwise_distances(Y, metric='manhattan') 
    # {'cosine', 'manhattan', 'cityblock', 'chebyshev', 'rogerstanimoto', 'mahalanobis', 'jaccard', 'hamming', 'nan_euclidean', 'seuclidean', 'precomputed', 'wminkowski', 'sokalsneath', 'dice', 'euclidean', 'braycurtis', 'sqeuclidean', 'l2', 'minkowski', 'correlation', 'sokalmichener', 'haversine', 'yule', 'l1', 'matching', 'canberra', 'russellrao'}
    
    window= 1
    N = len(ts) - window
    Y = np.array([ts[i:i+window] for i in range(N)])
    D = np.zeros((N, N))
    for i in range(N):
        for j in range(N):
            D[i, j] = dtw(Y[i], Y[j])

    return (D < eps).astype(int), D

# %%
data = pd.read_csv(OUT_PATH + '/grpPCA/supsubj_bb_mean/grp_Xtrans_PCA5.csv').query('freq == "broadband"').drop(columns = ['Unnamed: 0', 'subj', 'compo', 'freq']).values
condi1 = data[:3, int(data.shape[1]/2):]
condi2 = data[:3, :int(data.shape[1]/2)]

# %%
cmap_ev = {0 : 'Blues', 1 : 'Reds'}
for compo in range(2)  :
    fig, axs = plt.subplots(1, 3, figsize = (10, 5))
    fig.suptitle(f'RQA plot -- compo {compo + 1}')
    fig.tight_layout()
    R_ =[]
    for ev_i, x in enumerate([condi1, condi2]) :
        R, D = recurrence_plot(x[compo, :])
        sns.heatmap(R, ax=axs[ev_i], cmap=cmap_ev[ev_i], xticklabels=False, yticklabels=False, vmin = 0)

        R_.append(R)

    sns.heatmap(R_[0] - R_[1], ax=axs[2], cmap='coolwarm', xticklabels=False, yticklabels=False)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 8
#       6 R_ =[]
#       7 for ev_i, x in enumerate([condi1, condi2]) :
# ----> 8     R, D = recurrence_plot(x[compo, :])
#       9     sns.heatmap(R, ax=axs[ev_i], cmap=cmap_ev[ev_i], xticklabels=False, yticklabels=False, vmin = 0)
#      11     R_.append(R)
#
# Cell In[2], line 16, in recurrence_plot(ts, eps, tau, m)
#      14 for i in range(N):
#      15     for j in range(N):
# ---> 16         D[i, j] = dtw(Y[i], Y[j])
#      18 return (D < eps).astype(int), D
#
# File /opt/anaconda3/envs/MEGEEG/lib/python3.12/site-packages/tslearn/metrics/dtw_variants.py:786, in dtw(s1, s2, global_constraint, sakoe_chiba_radius, itakura_max_slope, be)
#     671 def dtw(
#     672     s1,
#     673     s2,
#    (...)    677     be=None,
#     678 ):
#     679     r"""Compute Dynamic Time Warping (DTW) similarity measure between
#     680     (possibly multidimensional) time series and return it.
#     681
#    (...)    784
#     785     """  # noqa: E501
# --> 786     be = instantiate_backend(be, s1, s2)
#     787     s1 = to_time_series(s1, remove_nans=True, be=be)
#     788     s2 = to_time_series(s2, remove_nans=True, be=be)
#
# File /opt/anaconda3/envs/MEGEEG/lib/python3.12/site-packages/tslearn/backend/backend.py:34, in instantiate_backend(*args)
#      32 if isinstance(arg, Backend):
#      33     return arg
# ---> 34 arg_string = (str(type(arg)) + str(arg)).lower()
#      35 if "numpy" in arg_string:
#      36     return Backend("numpy")
#
# File /opt/anaconda3/envs/MEGEEG/lib/python3.12/site-packages/numpy/_core/arrayprint.py:1669, in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1663 if a.shape == ():
#    1664     # obtain a scalar and call str on it, avoiding problems for subclasses
#    1665     # for which indexing with () returns a 0d instead of a scalar by using
#    1666     # ndarray's getindex. Also guard against recursive 0d object arrays.
#    1667     return _guarded_repr_or_str(np.ndarray.__getitem__(a, ()))
# -> 1669 return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#
# File /opt/anaconda3/envs/MEGEEG/lib/python3.12/site-packages/numpy/_core/arrayprint.py:762, in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     759 if a.size == 0:
#     760     return "[]"
# --> 762 return _array2string(a, options, separator, prefix)
#
# File /opt/anaconda3/envs/MEGEEG/lib/python3.12/site-packages/numpy/_core/arrayprint.py:534, in _recursive_guard.<locals>.decorating_function.<locals>.wrapper(self, *args, **kwargs)
#     532 repr_running.add(key)
#     533 try:
# --> 534     return f(self, *args, **kwargs)
#     535 finally:
#     536     repr_running.discard(key)
#
# File /opt/anaconda3/envs/MEGEEG/lib/python3.12/site-packages/numpy/_core/arrayprint.py:560, in _array2string(a, options, separator, prefix)
#     557     summary_insert = ""
#     559 # find the right formatting function for the array
# --> 560 format_function = _get_format_function(data, **options)
#     562 # skip over "["
#     563 next_line_prefix = " "
#
# File /opt/anaconda3/envs/MEGEEG/lib/python3.12/site-packages/numpy/_core/arrayprint.py:493, in _get_format_function(data, **options)
#     491         return formatdict['longfloat']()
#     492     else:
# --> 493         return formatdict['float']()
#     494 elif issubclass(dtypeobj, _nt.complexfloating):
#     495     if issubclass(dtypeobj, _nt.clongdouble):
#
# File /opt/anaconda3/envs/MEGEEG/lib/python3.12/site-packages/numpy/_core/arrayprint.py:432, in _get_formatdict.<locals>.<lambda>()
#     423 def _get_formatdict(data, *, precision, floatmode, suppress, sign, legacy,
#     424                     formatter, **kwargs):
#     425     # note: extra arguments in kwargs are ignored
#     426
#     427     # wrapped in lambdas to avoid taking a code path
#     428     # with the wrong type of data
#     429     formatdict = {
#     430         'bool': lambda: BoolFormat(data),
#     431         'int': lambda: IntegerFormat(data, sign),
# --> 432         'float': lambda: FloatingFormat(
#     433             data, precision, floatmode, suppress, sign, legacy=legacy),
#     434         'longfloat': lambda: FloatingFormat(
#     435             data, precision, floatmode, suppress, sign, legacy=legacy),
#     436         'complexfloat': lambda: ComplexFloatingFormat(
#     437             data, precision, floatmode, suppress, sign, legacy=legacy),
#     438         'longcomplexfloat': lambda: ComplexFloatingFormat(
#     439             data, precision, floatmode, suppress, sign, legacy=legacy),
#     440         'datetime': lambda: DatetimeFormat(data, legacy=legacy),
#     441         'timedelta': lambda: TimedeltaFormat(data),
#     442         'object': lambda: _object_format,
#     443         'void': lambda: str_format,
#     444         'numpystr': lambda: repr_format}
#     446     # we need to wrap values in `formatter` in a lambda, so that the interface
#     447     # is the same as the above values.
#     448     def indirect(x):
#
# File /opt/anaconda3/envs/MEGEEG/lib/python3.12/site-packages/numpy/_core/arrayprint.py:964, in FloatingFormat.__init__(self, data, precision, floatmode, suppress_small, sign, legacy)
#     961 self.exp_format = False
#     962 self.large_exponent = False
# --> 964 self.fillFormat(data)
#
# File /opt/anaconda3/envs/MEGEEG/lib/python3.12/site-packages/numpy/_core/arrayprint.py:973, in FloatingFormat.fillFormat(self, data)
#     971 abs_non_zero = absolute(finite_vals[finite_vals != 0])
#     972 if len(abs_non_zero) != 0:
# --> 973     max_val = np.max(abs_non_zero)
#     974     min_val = np.min(abs_non_zero)
#     975     with errstate(over='ignore'):  # division can overflow
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(figsize = (5, 5))
fig.suptitle('Time embedding plot')
fig.tight_layout()

color_ev =  {0 : 'b', 1 : 'r'}
for ev_i, x in enumerate([condi1, condi2]): 
    ax.plot(x[0, :], x[1, :] , c = color_ev[ev_i], label = ev_i + 1, alpha = 0.4)
ax.set_ylabel(f'PC2')
ax.set_xlabel(f'PC1')
ax.legend()

# %%
data = pd.read_csv(OUT_PATH + '/grpPCA/supsubj_mean/grp_mean_Xtrans_PCA3.csv').query('freq == "high_gamma"').drop(columns = ['Unnamed: 0', 'subj', 'expl_var', 'compo', 'freq']).values
condi2 = data[:2, int(data.shape[1]/2):]
condi1 = data[:2, :int(data.shape[1]/2)]

# %%
mean_list = []
mean_tfr_per_condi  =[]

from utils import ExcludSubj, TFRmEvents
import os

subj_included = [file.replace('_TFRtrials.p', '') for file in os.listdir(OUT_PATH + '/Data_shortWOBS') if file[-len('TFRtrials.p'):] == 'TFRtrials.p']
subj_included = ExcludSubj(subj_included, data_path=OUT_PATH + '/Data_shortWOBS')
interesting_ev = [0, 1]

for subj in subj_included : 
    TFRm = TFRmEvents(subj, data_path=OUT_PATH + '/Data_shortWOBS')
    mean_list.append(np.mean(TFRm[interesting_ev, :, :,:], axis = 0))
    mean_tfr_per_condi.append(TFRm[interesting_ev, :, :,:])

mean_all = np.concatenate(mean_list, axis = 0)
mean_tfr_per_condi_all = np.concatenate(mean_tfr_per_condi, axis = 1)

df_Componants_mean = pd.read_csv(OUT_PATH + '/grpPCA/supsubj_mean/grp_mean_compo_PCA3.csv').drop(columns='Unnamed: 0')

nb_compo=2

band = 'high_gamma'
i_b = 6

weights = df_Componants_mean.query('freq == @band').drop(columns = ['compo', 'freq']).values[:2, :]
data1 = weights @ mean_tfr_per_condi_all[0,:, i_b, :]
data2 = weights @ mean_tfr_per_condi_all[1,:, i_b, :]
data = np.concat([data1, data2], axis = 1)

# %%
condi1=data1
condi2=data2

# %%
cmap_ev = {0 : 'RdPu', 1 : 'Greens'}
for compo in range(2)  :
    fig, axs = plt.subplots(1, 3, figsize = (10, 5))
    fig.suptitle(f'RQA plot -- compo {compo + 1}')
    fig.tight_layout()
    R_ =[]
    for ev_i, x in enumerate([condi1, condi2]) :
        R, D = recurrence_plot(x[compo, :])
        sns.heatmap(R, ax=axs[ev_i], cmap=cmap_ev[ev_i], xticklabels=False, yticklabels=False)

        R_.append(R)

    sns.heatmap(R_[0] - R_[1], ax=axs[2], cmap='PiYG', xticklabels=False, yticklabels=False)
    plt.show()

# %%
fig, ax = plt.subplots(figsize = (5, 5))
fig.suptitle('Time embedding plot')
fig.tight_layout()

color_ev =  {0 : 'm', 1 : 'g'}
for ev_i, x in enumerate([condi1, condi2]): 
    ax.plot(x[0, :], x[1, :] , c = color_ev[ev_i], label = ev_i + 1, alpha = 0.4)
ax.set_ylabel(f'PC1')
ax.set_xlabel(f'PC2')
ax.legend()
