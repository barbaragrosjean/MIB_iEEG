# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 
import json 
import seaborn as sns 
from nilearn import plotting 
plt.style.use('petroff10')
import matplotlib.ticker as mticker
import matplotlib.gridspec as gridspec
import matplotlib.ticker as mticker
from matplotlib.lines import Line2D
from matplotlib.colors import LinearSegmentedColormap

from sklearn.decomposition import PCA 

#scripts_path = os.path('/scripts')
#from sys import path; path.append('scripts')

from scipy.stats import spearmanr
from src.config import col_pc, cmap_pcs, OUT_PATH, FREQ_BAND, color_event, COL_REG
from src.setting import ExcludSubj, GetInfo, get_data_grp
from src.decoding import cleandfdecodingTS

# %%
dataset_label = 'mf70-160'
tfr_path = OUT_PATH+ f'/Data_longWOBS_{dataset_label}'
subj_included = [file.replace('_TFRtrials.p', '') for file in os.listdir(tfr_path) if file[-len('TFRtrials.p'):] == 'TFRtrials.p']
subj_included = ExcludSubj(subj_included, data_path=tfr_path)
print(f"Subject Nbr is {len(subj_included)}")


path = tfr_path + f'/{subj_included[0]}_info.json'
with open(path) as json_data:
    d = json.load(json_data)
    time_epoch = d['time_epoch']
    time_tfr=d['time_tfr']
     
coord, areas, elect_list, subj_list, regions = GetInfo(subj_included, data_path=tfr_path)
region = regions

colors = plt.get_cmap('tab10')
element_colors = {elem: colors(i % 10) for i, elem in enumerate(FREQ_BAND)}
element_colors['broadband'] = 'black'
#colors = plt.get_cmap('tab10')
#element_colors = {elem: colors((i+3)**3 + 50) for i, elem in enumerate(FREQ_BAND)}
# Out:
# Subject Nbr is 30

# %% [markdown]
# # 2. Pres of res

# %% [markdown]
# - Plot with all of them PCA-Concat with trials transform and mean transform
# - Plot all heatmap stability accorss the 2 methods
# - Plot the LOO-subject
# - Plot the expl var with all of them

# %%
method_pca = 'concat'
data_aug_method = 'duplicat'
nb_compo = 10
interesting_ev = [0, 1]

# %%
fig, ax = plt.subplots(3,7, figsize = (20, 10))
df_list_transf = []

df_X_transformed_concat = pd.read_csv(f'{OUT_PATH}/grpPCA_{dataset_label}/supsubj_concat/grp_concat_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0', 'expl_var'])
df_X_transformed_mean = pd.read_csv(f'{OUT_PATH}/grpPCA_{dataset_label}/supsubj_mean/grp_mean_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0'])

for i_b, band in enumerate(FREQ_BAND) :# + ['broadband']) : 
    time = time_tfr
    if band =='broadband' : 
        df_X_transformed_concat = pd.read_csv(f'{OUT_PATH}/grpPCA/supsubj_bb_concat/grp_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0'])
        df_X_transformed_mean = pd.read_csv(f'{OUT_PATH}/grpPCA/supsubj_bb_mean/grp_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0'])
        time = time_epoch

    data_concat = df_X_transformed_concat.query('freq == @band').drop(columns = ['compo', 'freq', 'subj']).values
    data_mean = df_X_transformed_mean.query('freq == @band').drop(columns = ['compo', 'freq', 'subj']).values


    for i in range(3) : 
        # CONCAT
        ax[i][i_b].plot(time, data_concat[i, :int(data_concat.shape[1]/2)], label = f'M -- PCA-Concatenation', ls = '-', c = color_event[interesting_ev[0]], linewidth=0.5)
        ax[i][i_b].plot(time, data_concat[i, int(data_concat.shape[1]/2):], label = f'N -- PCA-Concatenation', ls = '-', c= color_event[interesting_ev[1]], linewidth=0.5)

        # MEAN
        ax[i][i_b].plot(time, data_mean[i, :int(data_mean.shape[1]/2)], label = f'M -- PCA-Mean', ls = ':', c = color_event[interesting_ev[0]], linewidth=1.5)
        ax[i][i_b].plot(time, data_mean[i, int(data_mean.shape[1]/2):], label = f'N -- PCA-Mean', ls = ':', c= color_event[interesting_ev[1]], linewidth=1.5)

        #ax[-1][-1].legend(bbox_to_anchor = (-1, -0.25), ncol = 4, loc='center')

        ax[i][i_b].grid()
        ax[i][0].set_ylabel('PC' + str(i+1))
        ax[i][i_b].set_xlabel('Time (s)')

    ax[0][i_b].set_title(band.replace('_', ' ').capitalize())

legend_lines=[Line2D([0], [0], linestyle='--', color='k', label='PCA-Concatenation'), 
              Line2D([0], [0], linestyle=':', color='k', label='PCA-Mean'),
              Line2D([0], [0], linestyle='None', marker='s', markersize=10,markerfacecolor=color_event[0], markeredgecolor=color_event[0], label='Memorized'), 
              Line2D([0], [0], linestyle='None', marker='s', markersize=10,markerfacecolor=color_event[1], markeredgecolor=color_event[1], label='Novel')]
              
ax[-1][-1].legend(handles= legend_lines, bbox_to_anchor = (0, -0.2), ncol=2)

# %%
# CORRELATION WIEGHT BETWEEN METHOD
df_mean_compo=pd.read_csv(f'{OUT_PATH}/grpPCA_mf70-160/supsubj_mean/grp_mean_Compo_PCA5.csv').drop(columns = ['Unnamed: 0', 'compo'])
df_concat_compo=pd.read_csv(f'{OUT_PATH}/grpPCA_mf70-160/supsubj_concat/grp_concat_Compo_PCA5.csv').drop(columns = ['Unnamed: 0', 'compo'])
fig, ax = plt.subplots(2, int((len(FREQ_BAND)+1)/2), figsize = (len(FREQ_BAND*3), 8))
#fig, ax = plt.subplots(1, len(FREQ_BAND), figsize = (len(FREQ_BAND)*5, 4))

for a, freq in zip(ax.flatten(), FREQ_BAND) :

    mean_compo = df_mean_compo.query('freq == @freq').drop(columns = 'freq').values
    concat_compo = df_concat_compo.query('freq == @freq').drop(columns = 'freq').values

    R = np.zeros((mean_compo.shape[0], concat_compo.shape[0]))
    P = np.zeros((mean_compo.shape[0], concat_compo.shape[0]))

    for i in range(mean_compo.shape[0]):
        for j in range(concat_compo.shape[0]):
            r, pval = spearmanr(mean_compo[i, :], concat_compo[j, :])
            R[i, j] = r
            P[i, j] = pval

    sns.heatmap(abs(R), vmin=0, vmax=1, cmap='Greys', ax=a, annot=True , fmt='.2f', cbar=True)
    a.set_xticklabels(['PC' + str(i+1) for i in range(5)])
    a.set_yticklabels(['PC' + str(i+1) for i in range(5)])
    a.set_title(freq.capitalize().replace('_', ' '))

mean_compo=pd.read_csv(f'{OUT_PATH}/grpPCA/supsubj_bb_mean/grp_Compo_PCA5.csv').drop(columns = ['Unnamed: 0', 'compo', 'freq']).values
concat_compo=pd.read_csv(f'{OUT_PATH}/grpPCA/supsubj_bb_concat/grp_Compo_PCA5.csv').drop(columns = ['Unnamed: 0', 'compo', 'freq']).values

R = np.zeros((mean_compo.shape[0], concat_compo.shape[0]))
P = np.zeros((mean_compo.shape[0], concat_compo.shape[0]))

for i in range(mean_compo.shape[0]):
    for j in range(concat_compo.shape[0]):
        r, pval = spearmanr(mean_compo[i, :], concat_compo[j, :])
        R[i, j] = r
        P[i, j] = pval

sns.heatmap(abs(R), vmin=0, vmax=1, cmap='Greys', ax=ax[-1][-1], annot=True , fmt='.2f')
ax[-1][-1].set_xticklabels(['PC' + str(i+1) for i in range(concat_compo.shape[0])])
ax[-1][-1].set_yticklabels(['PC' + str(i+1) for i in range(mean_compo.shape[0])])
#ax[-1][j].set_ylabel('Mean method')
#ax[i][j].set_xlabel('Concat method')
ax[-1][-1].set_title('Broadband')

# ax[0].set_ylabel('Mean method')
# for j in range(len(FREQ_BAND)):
#     ax[j].set_xlabel('Concat method')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 26
#      23     a.set_yticklabels(['PC' + str(i+1) for i in range(5)])
#      24     a.set_title(freq.capitalize().replace('_', ' '))
# ---> 26 mean_compo=pd.read_csv(f'{OUT_PATH}/grpPCA/supsubj_bb_mean/grp_Compo_PCA5.csv').drop(columns = ['Unnamed: 0', 'compo', 'freq']).values
#      27 concat_compo=pd.read_csv(f'{OUT_PATH}/grpPCA/supsubj_bb_concat/grp_Compo_PCA5.csv').drop(columns = ['Unnamed: 0', 'compo', 'freq']).values
#      29 R = np.zeros((mean_compo.shape[0], concat_compo.shape[0]))
#
# ...

# %%
# EXPL VAR
exp_list = []

## BB
data_grp = get_data_grp(data_path = tfr_path, subj_included = subj_included, type_data='epoch')
exp_var = pd.DataFrame()
pca = PCA(data_grp.shape[-1])

pca.fit(data_grp.mean(0).T)
exp_var['mean'] = pca.explained_variance_ratio_

pca.fit(np.concat([data_grp[0, :,:], data_grp[1, :,:]], axis=1).T)
exp_var['concat'] = pca.explained_variance_ratio_

exp_var['freq']=['broadband']*len(exp_var)
exp_var['PC']=['PC' + str(i+1) for i in range(len(exp_var))]
exp_list.append(exp_var)

# %%
## tfr
data_grp = get_data_grp(data_path = tfr_path, subj_included = subj_included, type_data='tfr')
for ib, band in enumerate(FREQ_BAND) :
    exp_var = pd.DataFrame()
    data= data_grp[:, :, ib, :]
    pca = PCA(data_grp.shape[-1])

    pca.fit(data.mean(0).T)
    exp_var['mean'] = pca.explained_variance_ratio_
    pca.fit(np.concat([data[0, :,:], data[1, :,:]], axis=1).T)
    exp_var['concat'] = pca.explained_variance_ratio_

    exp_var['freq']=[band]*len(exp_var)
    exp_var['PC']=['PC' + str(i+1) for i in range(len(exp_var))]

    exp_list.append(exp_var)

# %%
colors = plt.get_cmap('tab10')
element_colors = {elem: colors(i % 10) for i, elem in enumerate(FREQ_BAND)}
element_colors['broadband'] = 'black'

fig, ax = plt.subplots(1, 2, sharey=True, figsize = (13, 4))
fig.suptitle('Explained variance plot for n=5')

expl_var = pd.concat(exp_list)
expl_var['mean'] = expl_var['mean']*100
expl_var['concat'] = expl_var['concat']*100

expl_var_ = expl_var[expl_var['PC'].isin(['PC'+ str(i+1) for i in range(10)])]

sns.lineplot(data= expl_var_, x='PC', y='mean', hue = 'freq', palette=element_colors, ax=ax[0], linewidth = 1)
sns.lineplot(data= expl_var_, x='PC', y='concat', hue = 'freq', palette=element_colors, ax=ax[1], linewidth = 1)


ax[0].set_title('PCA-Mean')
ax[1].set_title('PCA-Concat')
ax[0].set_ylabel('Explained variance (%)')
ax[1].set_ylabel('')
ax[0].set_xlabel('Principal components')
ax[1].set_xlabel('Principal components')
ax[0].grid()
ax[1].grid()
ax[0].legend().remove()

ax[1].legend(bbox_to_anchor = (1.6, 1.03), title='Band Labels')

# %%
fig, ax = plt.subplots(figsize=(8, 3))
ax.plot(expl_var_[expl_var_['freq']== 'high_gamma']['PC'], expl_var_[expl_var_['freq']== 'high_gamma']['concat'], c='k')
ax.plot(expl_var_[expl_var_['freq']== 'high_gamma']['PC'], expl_var_[expl_var_['freq']== 'high_gamma']['mean'], c='k', ls=':')
ax.grid()
ax.set_ylabel('Explained Variance Ratio (%)')
# Out:
# Text(0, 0.5, 'Explained Variance Ratio (%)')

# %%
# effective dimentionnality 
expl_var = pd.concat(exp_list)

n2_mean = []
n2_concat = []
for band in  FREQ_BAND + ['broadband'] :
    expl_var_band = expl_var.query('freq == @band')
    n2_mean.append(sum(expl_var_band.loc[:, 'mean'])**2 / sum(expl_var_band.loc[:, 'mean']**2))
    n2_concat.append(sum(expl_var_band.loc[:, 'concat'])**2 / sum(expl_var_band.loc[:, 'concat']**2))

fig, ax = plt.subplots(1,1, figsize = (10, 3))
ax.plot(['broadband'] +FREQ_BAND, n2_mean, c='k' ,ls=':', label = 'PCA-Mean')
ax.plot(['broadband'] +FREQ_BAND, n2_concat,c='k', label = 'PCA-Concat')
ax.set_ylabel('ED')
ax.set_xticklabels(['broadband'] + [f.replace('_', ' ').capitalize() for f in FREQ_BAND])
ax.grid()
ax.legend()
# Out:
# /tmp/ipykernel_21635/473037829.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['broadband'] + [f.replace('_', ' ').capitalize() for f in FREQ_BAND])

# %%
# Stability
import pickle
with open(OUT_PATH + '/grpPCA_mf70-160/supsubj_concat/loo_stability.p', "rb") as f:
    loo_stability = pickle.load(f) # 30 , 5

with open(OUT_PATH + '/grpPCA_mf70-160/supsubj_concat/mean_corr_all.p', "rb") as f:
    mean_corr_all = pickle.load(f) # 5

with open(OUT_PATH + '/grpPCA_mf70-160/supsubj_concat/mean_corr_tr.p', "rb") as f:
    mean_corr_tr = pickle.load(f)

# %%
# STABILITY BETWEEN SUBJ 
from src.analysis import loso_pca_stability, intersubject_correlation
from src.setting import get_data_grp
from sklearn.decomposition import PCA

# %%
data_grp = get_data_grp(subj_included = subj_included, type_data='epoch', data_path=tfr_path)
#data_grp_ = np.concat([data_grp[i, :, :] for i in [0, 1]], axis =1)
data_grp_ = np.mean(data_grp, axis =0)
nb_compo= 3
metric_stab_subj = pd.DataFrame(columns = ['freq','PC','LOO', 'iter-corr'])
pca = PCA(nb_compo)
pca.fit(data_grp_.T)
W = pca.components_

stability = loso_pca_stability(data_grp_, subj_list, 5, )

for i in range(nb_compo):
    metric_stab_subj.loc[i, 'LOO'] = np.round(stability.mean(axis=0), 4)[i]
    mean_r, _ = intersubject_correlation(data_grp_, subj_list, W, i)
    metric_stab_subj.loc[i, 'iter-corr'] = np.round(mean_r, 4)
    metric_stab_subj.loc[i, 'freq'] = 'broadband'
    metric_stab_subj.loc[i,'PC'] = 'PC' +str(i+1)

# %%
data_grp = get_data_grp(subj_included = subj_included, type_data='tfr', data_path=tfr_path)
list_metric = [metric_stab_subj]
method_pca ='concat'
for ib, band in enumerate(FREQ_BAND) : 
    data= data_grp[:, :, ib, :]
    if method_pca=='concat':
        data_grp_ = np.concat([data[0, :,:], data[1, :,:]], axis=1)
    else : 
        np.mean(data, axis=0)

    metric_stab_subj = pd.DataFrame(columns = ['freq','PC','LOO', 'iter-corr'])
    pca = PCA(nb_compo)
    pca.fit(data_grp_.T)
    W = pca.components_

    stability = loso_pca_stability(data_grp_, subj_list, 5, )

    for i in range(nb_compo):
        metric_stab_subj.loc[i, 'LOO'] = np.round(stability.mean(axis=0), 4)[i]
        mean_r, _ = intersubject_correlation(data_grp_, subj_list, W, i)
        metric_stab_subj.loc[i, 'iter-corr'] = np.round(mean_r, 4)
        metric_stab_subj.loc[i, 'freq'] = band
        metric_stab_subj.loc[i,'PC'] = 'PC' +str(i+1)

    list_metric.append(metric_stab_subj)

metric = pd.concat(list_metric)

# %%
metric.to_csv(OUT_PATH + f'/grpPCA_{dataset_label}/supsubj_{method_pca}/stability_subj.csv')

# %%
# correlation between trials
cor= pd.read_csv(OUT_PATH + f'/grpPCA_{dataset_label}/corrTrials_concat.csv').drop(columns = 'Unnamed: 0')
cor['PC'] = ['PC'+str(i + 1) for i in range(5)]*8

fre_band =[]
for band in FREQ_BAND :
    fre_band.extend([band]*5)
fre_band += ['broadband']*5

cor['freq'] = fre_band
cor['mean'] = (cor['New'] + cor['Old'])/2

# %%
# BB plot for comparison 
fig, ax = plt.subplots(3,2, figsize = (10, 10), sharey='row')
metric_mean = pd.read_csv(OUT_PATH + '/final/stability_subj_mean.csv').drop(columns = 'Unnamed: 0').query('freq != "broadband"')
metric_concat = pd.read_csv(OUT_PATH + '/final/stability_subj_concat.csv').drop(columns = 'Unnamed: 0').query('freq != "broadband"')
cor_concat= pd.read_csv(OUT_PATH + '/final/corrTrials_concat.csv').drop(columns = 'Unnamed: 0') #.query('freq == "broadband"')
cor_mean= pd.read_csv(OUT_PATH + '/final/corrTrials_mean.csv').drop(columns = 'Unnamed: 0') #.query('freq == "broadband"')

cor_mean['PC'] = ['PC'+str(i + 1) for i in range(5)]*8
cor_concat['PC'] = ['PC'+str(i + 1) for i in range(5)]*8

fre_band =[]
for band in FREQ_BAND :
    fre_band.extend([band]*5)
fre_band += ['broadband']*5

cor_mean['freq'] = fre_band
cor_mean['mean'] = (cor_mean['New'] + cor_mean['Old'])/2
cor_concat['freq'] = fre_band
cor_concat['mean'] = (cor_concat['New'] + cor_concat['Old'])/2
cor_concat = cor_concat.query('freq != "broadband"')
cor_mean = cor_mean.query('freq != "broadband"')    

for freq in FREQ_BAND :
    ax[0][0].plot(metric_mean.query('freq == @freq')['PC'], expl_var.query('freq == @freq')['mean'][:5], c=element_colors[freq], ls='--')
    ax[0][1].plot(metric_concat.query('freq == @freq')['PC'], expl_var.query('freq == @freq')['concat'][:5], c = element_colors[freq], ls=':')
    ax[1][0].plot(metric_mean.query('freq == @freq')['PC'], metric_mean.query('freq == @freq')['LOO'],c=element_colors[freq], ls='--')
    ax[1][1].plot(metric_concat.query('freq == @freq')['PC'], metric_concat.query('freq == @freq')['LOO'], c=element_colors[freq], ls=':')
    ax[2][0].plot(cor_concat.query('freq == @freq')['PC'], cor_concat.query('freq == @freq')['mean'], c=element_colors[freq], ls='--')
    ax[2][1].plot(cor_mean.query('freq == @freq')['PC'], cor_mean.query('freq == @freq')['mean'], c=element_colors[freq], ls=':')
ax[0][0].set_title('PCA-Mean')
ax[0][1].set_title('PCA-Concat')
ax[0][0].set_ylabel('Explained Variance Ratio (%)')
ax[1][0].set_ylabel('LOO-subject (r-squared) ')
ax[2][0].set_ylabel('LOO-trials (r-squared)')
for a in ax.flat:
    a.grid()
    
legend_lines = []
for i, freq in enumerate(FREQ_BAND):
    legend_lines.append(Line2D([0], [0], linestyle='-', color=element_colors[freq], label=freq.replace('_', ' ').capitalize()))

ax[2][1].legend(handles= legend_lines, bbox_to_anchor=(1.1,-0.1), ncol=7)

# %%
fig, ax = plt.subplots(1, 3, figsize = (10 ,3))
fig.tight_layout()
metric_mean = pd.read_csv(OUT_PATH + '/final/stability_subj_mean.csv').drop(columns = 'Unnamed: 0').query('freq == "broadband"')
metric_concat = pd.read_csv(OUT_PATH + '/final/stability_subj_concat.csv').drop(columns = 'Unnamed: 0').query('freq == "broadband"')
cor_concat= pd.read_csv(OUT_PATH + '/final/corrTrials_concat.csv').drop(columns = 'Unnamed: 0')
cor_mean= pd.read_csv(OUT_PATH + '/final/corrTrials_mean.csv').drop(columns = 'Unnamed: 0')

cor_mean['PC'] = ['PC'+str(i + 1) for i in range(5)]*8
cor_concat['PC'] = ['PC'+str(i + 1) for i in range(5)]*8

fre_band =[]
for band in FREQ_BAND :
    fre_band.extend([band]*5)
fre_band += ['broadband']*5

cor_mean['freq'] = fre_band
cor_mean['mean'] = (cor_mean['New'] + cor_mean['Old'])/2
cor_concat['freq'] = fre_band
cor_concat['mean'] = (cor_concat['New'] + cor_concat['Old'])/2
cor_concat = cor_concat.query('freq == "broadband"')
cor_mean = cor_mean.query('freq == "broadband"')


ax[0].plot(metric_mean['PC'], expl_var['mean'][:5], c='k', ls='--')
ax[0].plot(metric_mean['PC'], expl_var['concat'][:5], c = 'k', ls=':')

ax[1].plot(metric_mean['PC'], metric_mean['LOO'], c = 'k', ls='--')
ax[1].plot(metric_concat['PC'], metric_concat['LOO'], c = 'k', ls=':')

ax[2].plot(cor_concat['PC'], cor_concat['mean'], c = 'k', ls=':')
ax[2].plot(cor_mean['PC'], cor_mean['mean'], c = 'k', ls='--')

ax[0].set_title('Explained Variance Ratio (%)')
ax[1].set_title('LOO-subject (r-squared) ')
ax[2].set_title('LOO-trials (r-squared)')

for a in ax : 
    a.grid()

# %% [markdown]
# # 3. Summary on BB

# %%
models = {
    'broadband0': ('duplicat', 'SVC_linear'), 'broadband1': ('mean', 'LR'), "broadband2": ('mean', 'RandomForest')}

# %%
COL_REG = {
    # --- Memory system (distinct blues)
    'HPC':  '#0b2e8a',   # deep navy
    'PHC':  '#2457c5',   # strong blue
    'EC':  '#6fa3ff',   # light blue
    'PCC':  '#3b4f9f',   # blue–indigo
    'PRH' : '#528EA4',

    # --- Limbic / affective / reward (distinct purples)
    'AMY':  '#5b1a8e',   # deep violet
    'VS':   '#8e44ad',   # saturated purple
    'OFC':  '#c39bd3',   # light lavender

    # --- Prefrontal / executive control (clearly separated reds/oranges)
    'DLPFC':"#7c1f16",   # dark red
    'ACC':  "#aa3124",   # red
    'VLPFC':"#b46433",   # orange

    # --- Sensory–motor (clearly separated greens)
    'M1':       '#145a32',   # dark green
    'premotor': '#229954',   # medium green
    'S1':       '#7dcea0',   # light green

    # --- Auditory / temporal association (strongly separated pink–reds)
    'A1':  "#e00101",   # dark rose
    'STG': "#ae1a3d",   # crimson pink
    'STS': '#e04b78',   # saturated pink
    'MTG': "#fc92b2",   # light pink
    'TP':  "#fbb1b1",   # very pale rose

    # --- Insula (salience bridge: blue–cyan, isolated)
    'INS': '#f1c40f',

    # --- Parietal association (yellow–green, isolated)
    'parietal': '#a3cb38',

    # --- Thalamic relay (olive–brown, isolated)
    'THAL': '#7f6d1f',

}

# %%
band = 'broadband'
method_pca = 'mean'
compo = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_bb_{method_pca}/grp_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')
ts = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_bb_{method_pca}/grp_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0']).query('freq == @band')


for col in ['expl_var', 'compo', 'freq', 'subj'] : 
    if col in compo.columns : 
        compo = compo.drop(columns = col)

    if col in ts.columns : 
        ts = ts.drop(columns = col)


# data grp 
ts = ts.values
compo = compo.values

Xreconstruct=[]
PCS = [0, 1, 2]
for pc in PCS : 
    Xrec = compo[pc, None, :].T @ ts[pc, None, :]
    Xrec = np.concat([Xrec[None, :, :int(Xrec.shape[1]/2)], Xrec[None, :, int(Xrec.shape[1]/2):]], axis = 0)
    Xreconstruct.append([Xrec])
Xreconstruct = np.vstack(Xreconstruct)
ts_pc=np.concat([ts[None, PCS, :int(ts.shape[1]/2)], ts[None, PCS, int(ts.shape[1]/2):]], axis = 0)
     
# plot topo pc1, ts, pc2 for each tp
fig = plt.figure(figsize=(12, 8))
gs = gridspec.GridSpec(2, 2, height_ratios=[3/5, 2/5], hspace=0.5, wspace=0.3)
ax_TS = fig.add_subplot(gs[0, :])  
ax_w1 = fig.add_subplot(gs[1, 0], polar=True)
ax_w2 = fig.add_subplot(gs[1, 1], polar=True)

# Weights of the decoding model as a gradiant
weightLR = []
label_plot = []
for pc_use in range(3) : 
    data_aug_method = models[band + str(pc_use)][0]
    model_name = models[band + str(pc_use)][1]
    df_final = pd.read_csv(OUT_PATH + f'/Decoding_shuffled_trials/{band}/fullmodel/{method_pca}_{data_aug_method}_{pc_use}_{model_name}full.csv')
    result = cleandfdecodingTS(df_final, len(time_epoch))
    if result['acc'] < 0.7 :
        weightLR.append(np.zeros(len(time_epoch)))
        label_plot.append(False)
        continue
    label_plot.append(f'{model_name.replace("_", " ")} (acc: {np.round(result["acc"], 2)}), aug:{data_aug_method}')
    weight_mean= abs(result['weight_mean'])
    weight_sh_mean= abs(result['weight_sh_mean'])
    weight_sh_std= abs(result['weight_sh_std'])
    per = np.percentile(result['weight_sh'], 95, axis=0)
    weight_thr = np.where(weight_mean > per, weight_mean, 0)
    weight_prop =  weight_thr/(weight_sh_mean+ weight_sh_std)
    #weight_prop = np.where(weight <  weight_sh_mean + weight_sh_std, 0, weight)[0]
    weight_prop_mean= np.mean(weight_prop, axis=0) 
    weight_mean_norm = (weight_prop - weight_prop.min()) / (weight_prop.max() - weight_prop.min())
    weightLR.append(weight_mean_norm)

for i in range(len(time_epoch) - 1):
    for pc in range(3) : 
        ax_TS.fill_between(time_epoch[i:i+2],ts_pc[0, pc, i:i+2],ts_pc[1, pc, i:i+2],color=cmap_pcs[pc](weightLR[pc][i]),linewidth=0)

# TS
for pc_use in range(3) : 
    ax_TS.plot(time_epoch, ts_pc[0, pc_use, :].T, c=col_pc[pc_use], ls=':', linewidth = 1)
    ax_TS.plot(time_epoch, ts_pc[1, pc_use, :].T, c=col_pc[pc_use], ls='--', linewidth = 1)

ax_TS.grid()
ax_TS.set_xlabel('Time (s)')
ax_TS.set_title('PCs TIME SERIES')
#data_thr = CompoThr(compo, replace = 0) # np.nan)
data_thr = compo
df_data = pd.DataFrame(data_thr.T)
df_data['region'] = region

# missing regions 
df_data[PCS] = df_data[PCS].astype(float)
df_abs = df_data.copy().drop(columns = ['region']).apply(lambda x : abs(x))
df_abs['region'] = region
df_abs.loc[:, 'region'] = df_abs.loc[:, 'region'].fillna('NON')
df_abs = df_abs[df_abs['region'] != 'N']
# PLOT 
regions = np.unique(df_abs['region'])
n_regions = len(regions)

angles = np.linspace(0, 2 * np.pi, n_regions, endpoint=False)
angles = np.concatenate([angles, [angles[0]]])

# pos and neg sum /count 
for PC_use in PCS : 
    # mean of the absolute value --> wher is the main contribution
    means_abs = df_abs.groupby('region').mean().loc[:, PC_use].reindex(COL_REG.keys()).values
    means_abs = np.concatenate([means_abs, [means_abs[0]]])
    ax_w1.plot(angles, means_abs*1000, linewidth=1, label=f"PC{PC_use+1}", c = col_pc[PC_use])
    ax_w1.fill(angles, means_abs*1000, alpha=0.15, c = col_pc[PC_use])
    ax_w1.set_title('MEAN OF |WEIGHTS|', y=1.1)

    # largest 
    index_largest = df_abs.nlargest(100, columns = PC_use).index
    largest = df_data.loc[index_largest, :].groupby('region').count().loc[:, PC_use]
    largest = largest.reset_index()
    for reg in df_data['region'] : 
        if reg not in largest['region'].values :
            largest = pd.concat([largest, pd.DataFrame([[reg, 0]], columns = ['region', PC_use])])
    largest = largest.set_index('region').reindex(COL_REG.keys()).values
    largest = np.concatenate([largest, [largest[0]]])
    ax_w2.plot(angles, largest, linewidth=1, label=f"PC{PC_use}", c = col_pc[PC_use])
    ax_w2.fill(angles, largest, alpha=0.15, c = col_pc[PC_use])
    ax_w2.set_title('LARGEST |WEIGHTS| COUNT', y=1.1)

    pos_sum = df_abs[[PC_use, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).values
    count = df_abs[[PC_use, 'region']].groupby('region').count().reindex(COL_REG.keys()).fillna(0).values

    pos_sum = np.concatenate([pos_sum, [pos_sum[0]]])
    count = np.concatenate([count, [count[0]]])

    
for a in [ax_w1, ax_w2] : 
    a.set_xticks(angles[:-1])
    a.set_xticklabels(COL_REG.keys(), fontsize=8)
    a.set_theta_offset(np.pi / 2)
    a.set_theta_direction(-1)

ax_w1.legend(
        loc='upper left',
        bbox_to_anchor=(-0.1, 1.5), ncol  =3)
ax_TS.legend( bbox_to_anchor=(1, -0.1), ncol=2)


legend_lines = [Line2D([0], [0], linestyle=':', color='black', label='Old'),
                Line2D([0], [0], linestyle='--', color='black', label='New')]

for i, model in enumerate(label_plot): 
    if model is not False:
       legend_lines.append(Line2D([0], [0], linestyle='None', marker='s', markersize=10,
           markerfacecolor=col_pc[i], markeredgecolor=col_pc[i], label=model))

ax_TS.legend(handles= legend_lines, bbox_to_anchor=(1,-0.05), ncol=2)
# Out:
# /var/folders/rr/sx7rgrrj3p12hz70crvxqcjc0000gn/T/ipykernel_3528/2438931018.py:127: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_TS.legend( bbox_to_anchor=(1, -0.1), ncol=2)

# %% [markdown]
# # 4. summary on TFRm

# %%
models = {
    'delta0': ('duplicat', 'LR'), 'delta1':('duplicat', 'SVC_linear'), "delta2" : ('mean', 'LR'),
    'theta0': ('mean', 'SVC_linear'), 'theta1':(None, None), "theta2" : (None, None),
    'alpha0': ('mean', 'LR'), 'alpha1':( 'mean', 'LR'), "alpha2" : ( 'mean', 'LR'),
    'low_beta0': ('mean', 'LR'), 'low_beta1':( 'mean', 'LR'), "low_beta2" : ( 'mean', 'LR'),
    'high_beta0': ('mean', 'LR'), 'high_beta1':( 'duplicat', 'LR'), "high_beta2" : ( 'mean', 'LR'),
    'high_gamma0': ('duplicat', 'RandomForest'), 'high_gamma1':('mean', 'SVC_linear'), "high_gamma2" : ( 'duplicat', 'LR') }

# %%
band = 'high_gamma'
method_pca = 'concat'
PCS = [0, 1, 2]

compo = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')
ts = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0']).query('freq == @band')

for col in ['expl_var', 'compo', 'freq', 'subj'] : 
    if col in compo.columns : 
        compo = compo.drop(columns = col)

    if col in ts.columns : 
        ts = ts.drop(columns = col)


# data grp 
ts = ts.values
compo = compo.values

ts_pc=np.concat([ts[None, PCS, :int(ts.shape[1]/2)], ts[None, PCS, int(ts.shape[1]/2):]], axis = 0)

if band == 'alpha' :  # flip alpha
    ts_pc[:, 1, :] = - ts_pc[:, 1,:]
    compo[1, :] = - compo[1, :]

# plot topo pc1, ts, pc2 for each tp
fig = plt.figure(figsize=(12, 8))
gs = gridspec.GridSpec(2, 4, height_ratios=[3/5, 2/5], hspace=0.5, wspace=0.3)
ax_TS = fig.add_subplot(gs[0, :])  
ax_w1 = fig.add_subplot(gs[1, 0], polar=True)
ax_w2 = fig.add_subplot(gs[1, 1], polar=True)
ax_w3 = fig.add_subplot(gs[1, 2], polar=True)
ax_w4 = fig.add_subplot(gs[1, 3], polar=True)

# Weights of the decoding model as a gradiant
from src.decoding import cleandfdecodingTS
weightLR = []
label_plot =[]
for pc_use in PCS : 
    data_aug_method = models[band + str(pc_use)][0]
    model = models[band + str(pc_use)][1]
    if model == None :
        label_plot.append(False)
        weightLR.append(np.zeros(len(time_tfr)))
        continue
    df_final = pd.read_csv(OUT_PATH + f'/Decoding_shuffled_trials_full/{band}/fullmodel/{method_pca}_{data_aug_method}_{pc_use}_{model}full.csv')
    result = cleandfdecodingTS(df_final, len(time_tfr))
    
    if result['acc'] < 0.7 :
        weightLR.append(np.zeros(len(time_tfr)))
        label_plot.append(False)
        continue

    label_plot.append(f'{model.replace("_", " ")} (acc: {np.round(result["acc"], 2)}), aug:{data_aug_method}')
    weight_mean= abs(result['weight_mean'])
    weight_sh_mean= abs(result['weight_sh_mean'])
    weight_sh_std= abs(result['weight_sh_std'])
    per = np.percentile(result['weight_sh'], 95, axis=0)
    weight_thr = np.where(weight_mean > per, weight_mean, 0)
    weight_prop =  weight_thr/(weight_sh_mean+ weight_sh_std)
    #weight_prop = np.where(weight <  weight_sh_mean + weight_sh_std, 0, weight)[0]
    weight_prop_mean= np.mean(weight_prop, axis=0) 
    weight_mean_norm = (weight_prop - weight_prop.min()) / (weight_prop.max() - weight_prop.min())
    weightLR.append(weight_mean_norm)

for i in range(len(time_tfr) - 1):
    for pc in PCS : 
        model = models[band + str(pc)][1]
        if model == None :
            continue
        #ax_TS.fill_between(time_tfr[i:i+2],ts_pc[0, pc, i:i+2],ts_pc[1, pc, i:i+2],color=cmap_pcs[pc](weightLR[pc][i]),linewidth=0)
    
for pc_use in PCS : 
    ax_TS.plot(time_tfr, ts_pc[0, pc_use, :].T, c=col_pc[pc_use], ls=':', linewidth = 1)
    ax_TS.plot(time_tfr, ts_pc[1, pc_use, :].T, c=col_pc[pc_use], ls='--', linewidth = 1)

ax_TS.grid()
ax_TS.set_xlabel('Time (s)')
ax_TS.set_title('PCs TIME SERIES')

#data_thr = CompoThr(compo, replace = 0) # np.nan)
data_thr = compo
df_data = pd.DataFrame(data_thr.T)
df_data['region'] = region

# missing regions 
df_data[[0, 1, 2, 3]] = df_data[[0, 1, 2, 3]].astype(float)
df_data = df_data[df_data['region'] != 'N']
df_abs = df_data.copy().drop(columns = ['region']).apply(lambda x : abs(x))
df_abs['region'] = df_data['region']
df_abs.loc[:, 'region'] = df_abs.loc[:, 'region'].fillna('NON')

# PLOT 
regions = np.unique(df_data['region'])
n_regions = len(regions)

angles = np.linspace(0, 2 * np.pi, n_regions, endpoint=False)
angles = np.concatenate([angles, [angles[0]]])


# pos and neg sum /count 
for PC_use in PCS : 
    # mean of the absolute value --> wher is the main contribution
    means_abs = df_abs.groupby('region').mean().loc[:, PC_use].reindex(COL_REG.keys()).drop(index='N').values
    means_abs = np.concatenate([means_abs, [means_abs[0]]])
    ax_w1.plot(angles, means_abs*1000, linewidth=1, label=f"PC{PC_use+1}", c = col_pc[PC_use])
    ax_w1.fill(angles, means_abs*1000, alpha=0.15, c = col_pc[PC_use])
    ax_w1.set_title('MEAN OF |WEIGHTS|', y=1.1)

    # largest 
    index_largest = df_abs.nlargest(100, columns = PC_use).index
    largest = df_data.loc[index_largest, :].groupby('region').count().loc[:, PC_use]
    largest = largest.reset_index()
    for reg in df_data['region'] : 
        if reg not in largest['region'].values :
            largest = pd.concat([largest, pd.DataFrame([[reg, 0]], columns = ['region', PC_use])])
    largest = largest.set_index('region').reindex(COL_REG.keys()).drop(index='N').values
    largest = np.concatenate([largest, [largest[0]]])
    # add
    largest = largest[:, 0]

    ax_w2.plot(angles, largest, linewidth=1, label=f"PC{PC_use}", c = col_pc[PC_use])
    ax_w2.fill(angles, largest, alpha=0.15, c = col_pc[PC_use])
    ax_w2.set_title('LARGEST |WEIGHTS| COUNT', y=1.1)

    pos_sum = df_data[df_data[PC_use] > 0][[PC_use, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).drop(index='N').values
    neg_sum = df_data[df_data[PC_use] < 0][[PC_use, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).drop(index='N').values
    count = df_data[[PC_use, 'region']].groupby('region').count().reindex(COL_REG.keys()).fillna(0).drop(index='N').values

    pos_sum = np.concatenate([pos_sum, [pos_sum[0]]])[:, 0]
    neg_sum = np.concatenate([neg_sum, [neg_sum[0]]])[:, 0]
    count = np.concatenate([count, [count[0]]])[:, 0]

    ax_w3.plot(angles, pos_sum/count, linewidth=1, label=f"PC{PC_use}", c = col_pc[PC_use])
    ax_w3.fill(angles, pos_sum/count, alpha=0.15, c = col_pc[PC_use])
    ax_w3.set_title('(+) WEIGHT SUM/COUNT', y=1.1)

    ax_w4.plot(angles, -neg_sum/count, linewidth=1, label=f"PC{PC_use}", c = col_pc[PC_use],)
    ax_w4.fill(angles, -neg_sum/count, alpha=0.15, c = col_pc[PC_use])
    ax_w4.set_title('(-) WEIGHT SUM/COUNT', y=1.1)
    
    ax_w3.set_ylim(0, 0.03)
    ax_w4.set_ylim(0, 0.03)

    scale = 100  # change to 1e6 if you want micro-units etc.
    formatter = mticker.FuncFormatter(lambda x, pos: f"{x*scale:g}")
    ax_w3.yaxis.set_major_formatter(formatter)
    ax_w4.yaxis.set_major_formatter(formatter)

for a in [ax_w1, ax_w2, ax_w3, ax_w4] : 
    a.set_xticks(angles[:-1])
    a.set_xticklabels(list(COL_REG.keys())[:-1], fontsize=8)
    a.set_theta_offset(np.pi / 2)
    a.set_theta_direction(-1)

ax_w1.legend(
        loc='upper left',
        bbox_to_anchor=(-0.1, 1.5), ncol  =3)


legend_lines = []

#for i, model in enumerate(label_plot): 
    #if not model:
#    legend_lines.append(Line2D([0], [0], linestyle='None', marker='s', markersize=10,
#           markerfacecolor=col_pc[i], markeredgecolor=col_pc[i], label=model))

legend_lines.extend([Line2D([], [],linestyle='None', label='Conditions'), 
                     Line2D([0], [0], linestyle=':', color='black', label='Memorized'),
                Line2D([0], [0], linestyle='--', color='black', label='New')])

leg = ax_TS.legend(handles= legend_lines, bbox_to_anchor=(1.01, -0.03), ncol=1)

for h, txt in zip(leg.legend_handles, leg.get_texts()):
    if txt.get_text() == 'Conditions' :
        h.set_visible(False)
        txt.set_weight('bold')
        txt.set_x(-50)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 method_pca = 'concat'
#       3 PCS = [0, 1, 2]
# ----> 5 compo = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')
#       6 ts = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0']).query('freq == @band')
#       8 for col in ['expl_var', 'compo', 'freq', 'subj'] :
#
# ...

# %%
band = 'high_gamma'
method_pca = 'concat'
PCS = [0, 1, 2]

compo = pd.read_csv(OUT_PATH + f'/grpPCA_mf70-160/supsubj_{method_pca}/grp_{method_pca}_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')
ts = pd.read_csv(OUT_PATH + f'/grpPCA_mf70-160/supsubj_{method_pca}/grp_{method_pca}_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0']).query('freq == @band')

for col in ['expl_var', 'compo', 'freq', 'subj'] : 
    if col in compo.columns : 
        compo = compo.drop(columns = col)

    if col in ts.columns : 
        ts = ts.drop(columns = col)


# data grp 
ts = ts.values
compo = compo.values

ts_pc=np.concat([ts[None, PCS, :int(ts.shape[1]/2)], ts[None, PCS, int(ts.shape[1]/2):]], axis = 0)

if band == 'alpha' :  # flip alpha
    ts_pc[:, 1, :] = - ts_pc[:, 1,:]
    compo[1, :] = - compo[1, :]

# plot topo pc1, ts, pc2 for each tp
fig = plt.figure(figsize=(16, 12))
gs = gridspec.GridSpec(3, 4, height_ratios=[3/5, 2/5, 2/5], hspace=0.5, wspace=0.3)
ax_TS = fig.add_subplot(gs[0, :])  

ax_w0 = fig.add_subplot(gs[1, 0])
ax_w1 = fig.add_subplot(gs[1, 1])
ax_w2 = fig.add_subplot(gs[1, 2])

for i, a in enumerate([ax_w0, ax_w1, ax_w2]) :
    a.set_title('Network ' + str(i +1))

ax_w3 = fig.add_subplot(gs[1, 3], polar=True)
ax_w4 = fig.add_subplot(gs[2, 3], polar=True)

for pc_use in PCS : 
    ax_TS.plot(time_tfr[20:], ts_pc[0, pc_use, 20:].T, c=col_pc[pc_use], ls=':', linewidth = 2)
    ax_TS.plot(time_tfr[20:], ts_pc[1, pc_use, 20:].T, c=col_pc[pc_use], ls='--', linewidth = 2)

ax_TS.grid()
ax_TS.set_xlabel('Time (s)')
ax_TS.set_title('Network dynamics')

data_thr = compo
df_data = pd.DataFrame(data_thr.T)
df_data['region'] = region

# missing regions 
df_data[[0, 1, 2, 3]] = df_data[[0, 1, 2, 3]].astype(float)
df_data = df_data[df_data['region'] != 'N']
df_abs = df_data.copy().drop(columns = ['region']).apply(lambda x : abs(x))
df_abs['region'] = df_data['region']
df_abs.loc[:, 'region'] = df_abs.loc[:, 'region'].fillna('NON')

# PLOT 
regions = np.unique(df_data['region'])
n_regions = len(regions)

angles = np.linspace(0, 2 * np.pi, n_regions, endpoint=False)
angles = np.concatenate([angles, [angles[0]]])


# pos and neg sum /count 
for PC_use in PCS : 
    pos_sum = df_data[df_data[PC_use] > 0][[PC_use, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).drop(index='N').values
    neg_sum = df_data[df_data[PC_use] < 0][[PC_use, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).drop(index='N').values
    count = df_data[[PC_use, 'region']].groupby('region').count().reindex(COL_REG.keys()).fillna(0).drop(index='N').values

    pos_sum = np.concatenate([pos_sum, [pos_sum[0]]])[:, 0]
    neg_sum = np.concatenate([neg_sum, [neg_sum[0]]])[:, 0]
    count = np.concatenate([count, [count[0]]])[:, 0]

    ax_w3.plot(angles, pos_sum/count, linewidth=1, label=f"PC{PC_use}", c = col_pc[PC_use])
    ax_w3.fill(angles, pos_sum/count, alpha=0.15, c = col_pc[PC_use])
    ax_w3.set_title('Positve contribution', y=1.1)

    ax_w4.plot(angles, -neg_sum/count, linewidth=1, label=f"PC{PC_use}", c = col_pc[PC_use],)
    ax_w4.fill(angles, -neg_sum/count, alpha=0.15, c = col_pc[PC_use])
    ax_w4.set_title('Negative contribution', y=1.1)
    
    ax_w3.set_ylim(0, 0.04)
    ax_w4.set_ylim(0, 0.02)

    scale = 100  # change to 1e6 if you want micro-units etc.
    formatter = mticker.FuncFormatter(lambda x, pos: f"{x*scale:g}")
    ax_w3.yaxis.set_major_formatter(formatter)
    ax_w4.yaxis.set_major_formatter(formatter)

for a in [ax_w3, ax_w4] : 
    a.set_xticks(angles[:-1])
    a.set_xticklabels(list(COL_REG.keys())[:-1], fontsize=8)
    a.set_theta_offset(np.pi / 2)
    a.set_theta_direction(-1)

legend_lines = []
legend_lines = [Line2D([], [],linestyle='None', label='Time series'), 
                    Line2D([0], [0], color=col_pc[0], label='Network 1'),
                    Line2D([0], [0], color=col_pc[1], label='Network 2'),
                    Line2D([0], [0], color=col_pc[2], label='Network 3'),
                    Line2D([], [],linestyle='None', label='Conditions'), 
                    Line2D([0], [0], linestyle=':', color='black', label='Memorized'),
                    Line2D([0], [0], linestyle='--', color='black', label='Novel')]

leg = ax_TS.legend(handles= legend_lines, ncol=2)

for h, txt in zip(leg.legend_handles, leg.get_texts()):
    if txt.get_text() in ['Conditions',  'Time series']:
        h.set_visible(False)
        txt.set_weight('bold')
        txt.set_x(-20)
fig.savefig('out.pdf', bbox_inches='tight')

# %%
from src.decomposition import CompoThr

data_thr = CompoThr(compo, replace=np.nan)
df_data = pd.DataFrame(data_thr.T)
regions =region
for PC_use in PCS :
    pos = df_data.copy().clip(lower=0).values[:, PC_use]
    mask = (~np.isnan(pos)) & (pos > 0) & [n != 'N' for n in regions]
    values_filt = pos[mask]
    coords_filt = np.array(coord)[mask]
    corrected_coords = np.where(abs(coords_filt) >100, coords_filt*0.001, coords_filt)

    vmin = 0 #-np.max(np.abs(data)) 
    vmax = np.max(np.abs(values_filt))
    norm_signal = (values_filt - vmin) / (vmax - vmin)
    cmap = plt.cm.Reds
    colors = [tuple(cmap(val)) for val in norm_signal.flatten()]
    view = plotting.view_markers(corrected_coords, marker_color=colors,marker_size=5,title=f'PC{PC_use+1}', title_fontsize=25 )
    view.open_in_browser()

for PC_use in PCS :

    neg = - df_data.copy().clip(upper=0).values[:, PC_use]
    mask = (~np.isnan(neg)) & (neg > 0) & [n != 'N' for n in regions]
    values_filt = neg[mask]
    coords_filt = np.array(coord)[mask]
    corrected_coords = np.where(abs(coords_filt) > 100, coords_filt*0.001, coords_filt)

    vmin = 0 #-np.max(np.abs(data)) 
    vmax = np.max(np.abs(values_filt))
    norm_signal = (values_filt - vmin) / (vmax - vmin)
    cmap = plt.cm.Blues
    colors = [tuple(cmap(val)) for val in norm_signal.flatten()]
    view = plotting.view_markers(corrected_coords, marker_color=colors,marker_size=5,title=f'PC{PC_use+1}', title_fontsize=25 )
    view.open_in_browser()
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~/miniforge3/envs/mne_iEEG/lib/python3.10/site-packages/nilearn/_utils/html_document.py:65, in _open_in_browser(content)
#      64 try:
# ---> 65     queue.get(timeout=BROWSER_TIMEOUT_SECONDS)
#      66 except Empty:
#
# File ~/miniforge3/envs/mne_iEEG/lib/python3.10/queue.py:179, in Queue.get(self, block, timeout)
#     178 if remaining <= 0.0:
# --> 179     raise Empty
#     180 self.not_empty.wait(remaining)
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 19
#      17     colors = [tuple(cmap(val)) for val in norm_signal.flatten()]
#      18     view = plotting.view_markers(corrected_coords, marker_color=colors,marker_size=5,title=f'PC{PC_use+1}', title_fontsize=25 )
# ...

# %%
data_thr = CompoThr(compo, replace=np.nan)
df_data = pd.DataFrame(data_thr.T)

for PC_use in PCS : 
    
    pos = df_data.copy().clip(lower=0).values[:, PC_use]

    mask = (~np.isnan(pos)) & (pos > 0)
    values_filt = pos[mask]
    coords_filt = np.array(coord)[mask]

    fig = plotting.plot_markers(node_coords = np.array(coords_filt),  
                                      node_size=4, 
                                      node_values=values_filt,
                                      node_cmap='Reds',
                                      display_mode='ortho',
                                      node_vmin=0, 
                                      node_vmax=0.1) 
    fig.savefig(f'{PC_use}_topo_pos.pdf')
    neg = df_data.copy().clip(upper=0).values[:, PC_use]
    mask = (~np.isnan(neg)) & (neg < 0)
    values_filt = neg[mask]
    coords_filt = np.array(coord)[mask]

    fig = plotting.plot_markers(node_coords = np.array(coords_filt),  
                                      node_size=4, 
                                      node_values=-values_filt,
                                      node_cmap='Blues',
                                      display_mode='ortho', 
                                      node_vmin=0, 
                                      node_vmax=0.05) 
                               

    #fig.savefig(f'{PC_use}_topo_neg.pdf')

# %%
# for the same PC for a polar with neg and pos on the same plot 
band = 'alpha'
method_pca = 'concat'
PCS = [0, 1, 2]

compo = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')

for col in ['expl_var', 'compo', 'freq', 'subj'] : 
    if col in compo.columns : 
        compo = compo.drop(columns = col)

# data grp 
compo = compo.values

if band == 'alpha' : 
    compo[1, :] = - compo[1, :]

# plot topo pc1, ts, pc2 for each tp
fig = plt.figure(figsize=(15, 10))
gs = gridspec.GridSpec(3, 2, hspace=0.5, wspace=0.3)
ax_w1 = fig.add_subplot(gs[0, :], polar=True)
ax_w2 = fig.add_subplot(gs[1, :], polar=True)
ax_w3 = fig.add_subplot(gs[2, :], polar=True)

#data_thr = CompoThr(compo, replace = 0) # np.nan)
data_thr = compo
df_data = pd.DataFrame(data_thr.T)
df_data['region'] = region

# missing regions 
df_data[[0, 1, 2, 3]] = df_data[[0, 1, 2, 3]].astype(float)
df_data = df_data[df_data['region'] != 'N']
df_abs = df_data.copy().drop(columns = ['region']).apply(lambda x : abs(x))
df_abs['region'] = df_data['region']
df_abs.loc[:, 'region'] = df_abs.loc[:, 'region'].fillna('NON')

# PLOT 
n_regions = len(regions) -1

angles = np.linspace(0, 2 * np.pi, n_regions, endpoint=False)
angles = np.concatenate([angles, [angles[0]]])

# pos and neg sum /count 
for PC_use, ax in zip(PCS, [ax_w1, ax_w2, ax_w3]) : 
    pos_sum = df_data[df_data[PC_use] > 0][[PC_use, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).values
    neg_sum = df_data[df_data[PC_use] < 0][[PC_use, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).values
    count = df_data[[PC_use, 'region']].groupby('region').count().reindex(COL_REG.keys()).fillna(0).values

    pos_sum = np.concatenate([pos_sum, [pos_sum[0]]])
    neg_sum = np.concatenate([neg_sum, [neg_sum[0]]])
    count = np.concatenate([count, [count[0]]])

    ax.plot(angles, pos_sum/count, linewidth=1, c ='grey')
    ax.fill(angles, pos_sum/count, alpha=0.15, c = 'grey')
    ax.set_title(f"PC{PC_use +1}", y=1.1)

    ax.plot(angles, -neg_sum/count, linewidth=1, c = 'k',)
    ax.fill(angles, -neg_sum/count, alpha=0.15, c = 'k')
    
    ax.set_ylim(0, 0.03)
    ax.set_ylim(0, 0.03)

    scale = 100  # change to 1e6 if you want micro-units etc.
    formatter = mticker.FuncFormatter(lambda x, pos: f"{x*scale:g}")
    ax.yaxis.set_major_formatter(formatter)
    ax.yaxis.set_major_formatter(formatter)

for a in [ax_w1, ax_w2, ax_w3] : 
    a.set_xticks(angles[:-1])
    a.set_xticklabels(COL_REG.keys(), fontsize=8)
    a.set_theta_offset(np.pi / 2)
    a.set_theta_direction(-1)

legend_line = [Line2D([0], [0], linestyle='None', marker='s', markersize=10,
           markerfacecolor='b', markeredgecolor='b', label='Old/correct'), 
           Line2D([0], [0], linestyle='None', marker='s', markersize=10,
           markerfacecolor='r', markeredgecolor='r', label='New/correct')]
ax_w2.legend(handles =legend_line,
        loc='center',
        bbox_to_anchor=(0.5, -1.8), ncol  =1)

# %% [markdown]
# # Group FREQ

# %%
# sensory info flow 
# high gamma PC1, bb PC1
signals = [('high_gamma', 'concat', 0), ('broadband', 'mean', 0), ('theta', 'concat', 1)]
label_plt = 'Sensory inflow components'

# com with memory sensory system 
# high gamma PC3, theta PC1
signals = [('high_gamma', 'concat', 2), ('theta', 'concat', 0)]
label_plt = 'Memory components'

# release of inhibition 
# alpha PC1, lowbeta PC1, hgih beta PC1
signals = [('alpha', 'concat', 0), ('low_beta', 'concat', 0),  ('high_beta', 'concat', 0)]
signals = [('alpha', 'concat', 1), ('low_beta', 'concat', 1),  ('high_beta', 'concat', 1)]
label_plt = 'Release of inhibition components'

# decision making cognitive motor planning 
# bb PC2, high gamma PC2, 
signals = [('broadband', 'mean', 1), ('high_gamma', 'concat', 1), ('alpha', 'concat', 1), ('low_beta', 'concat', 1), ('high_beta', 'concat', 1)]
label_plt = 'Motor/cognitive components'

# ?? 
# signals = [('alpha', 'concat', 1), ('low_beta', 'concat', 1, ), ('high_beta', 'concat', 1), ('theta', 'concat', 1)]

signals = [('alpha', 'concat', 2), ('low_beta', 'concat', 2), ('high_beta', 'concat', 2)] #('theta', 'concat', 1)]
label_plt = '??'

# %%
colors = plt.get_cmap('tab10')
element_colors = {elem: colors(i % 10) for i, elem in enumerate(FREQ_BAND)}
element_colors['broadband'] = 'black'

# %%
signals = [('alpha', 'concat', 1), ('low_beta', 'concat',1), ('high_beta', 'concat',1)]

label_plt = 'PCs 1'

fig = plt.figure(figsize=(8, 5))
gs = gridspec.GridSpec(2, 2, hspace=0.6, wspace=0)
ax_TS = fig.add_subplot(gs[:, 0])  
ax_w3 = fig.add_subplot(gs[0, 1], polar=True)
ax_w4 = fig.add_subplot(gs[1, 1], polar=True)

legend_lines = [] 

# PLOT 
n_regions = len(regions) - 1

angles = np.linspace(0, 2 * np.pi, n_regions, endpoint=False)
angles = np.concatenate([angles, [angles[0]]])

for band, method_pca, pc in signals :
    # Get data
    compo = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')
    ts = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0']).query('freq == @band')
    for col in ['expl_var', 'compo', 'freq', 'subj'] : 
        if col in compo.columns : 
            compo = compo.drop(columns = col)

        if col in ts.columns : 
            ts = ts.drop(columns = col)
 
    ts = ts.values
    compo = compo.values
    ts_pc=np.concat([ts[None, :, :int(ts.shape[1]/2)], ts[None, :, int(ts.shape[1]/2):]], axis = 0)

    if band == 'alpha' :  # flip alpha
        ts_pc[:, 1, :] = - ts_pc[:, 1,:]
        compo[1, :] = - compo[1, :]

    df_data = pd.DataFrame(compo.T)
    df_data['region'] = region
    df_data = df_data[df_data['region'] != 'N']
    df_data[[0, 1, 2, 3]] = df_data[[0, 1, 2, 3]].astype(float)

    # PLOT TS
    ax_TS.plot(time_tfr, ts_pc[0, pc, :].T, c= element_colors[band], ls=':', label='Old')
    ax_TS.plot(time_tfr, ts_pc[1, pc, :].T, c=element_colors[band], ls='--', label='New')
    ax_TS.set_xlabel('Time (s)')
    
    # PLOT WEIGHTS
    pos_sum = df_data[df_data[pc] > 0][[pc, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).values
    neg_sum = df_data[df_data[pc] < 0][[pc, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).values
    count = df_data[[pc, 'region']].groupby('region').count().reindex(COL_REG.keys()).fillna(0).values

    pos_sum = np.concatenate([pos_sum, [pos_sum[0]]])
    neg_sum = np.concatenate([neg_sum, [neg_sum[0]]])
    count = np.concatenate([count, [count[0]]])

    ax_w3.plot(angles, pos_sum/count, linewidth=1, label=f"PC{pc}", c = element_colors[band])
    ax_w3.fill(angles, pos_sum/count, alpha=0.15, c = element_colors[band])
    ax_w3.set_title('(+) WEIGHT SUM/COUNT', y=1.1)

    ax_w4.plot(angles, -neg_sum/count, linewidth=1, label=f"PC{pc}", c = element_colors[band])
    ax_w4.fill(angles, -neg_sum/count, alpha=0.15, c = element_colors[band])
    ax_w4.set_title('(-) WEIGHT SUM/COUNT', y=1.1)
    
    ax_w3.set_ylim(0, 0.035)
    ax_w4.set_ylim(0, 0.035)

    scale = 100  # change units
    formatter = mticker.FuncFormatter(lambda x, pos: f"{x*scale:g}")
    ax_w3.yaxis.set_major_formatter(formatter)
    ax_w4.yaxis.set_major_formatter(formatter)

    for a in [ax_w3, ax_w4] : 
        a.set_xticks(angles[:-1])
        a.set_xticklabels(COL_REG.keys(), fontsize=8)
        a.set_theta_offset(np.pi / 2)
        a.set_theta_direction(-1)

    legend_lines.append(Line2D([0], [0], linestyle='None', marker='s', markersize=10,
           markerfacecolor=element_colors[band], markeredgecolor=element_colors[band], label=f'{band.replace('_', ' ').capitalize()}')) # PC{pc+1}'))

legend_lines.extend([Line2D([0], [0], linestyle=':', color='black', label='Old'),
                Line2D([0], [0], linestyle='--', color='black', label='New')])
ax_TS.grid()
ax_TS.set_title(f'{label_plt}')

ax_TS.legend(handles= legend_lines, bbox_to_anchor=(1.01, -0.1), ncol=5)

# %%
signals = [('broadband', 'mean', 0), ('high_gamma', 'concat', 0), ('theta', 'concat', 1)]
label_plt = 'Memory components'

fig = plt.figure(figsize=(8, 8))
gs = gridspec.GridSpec(3, 3, hspace=0.6, wspace=0)
ax_TS_bb = fig.add_subplot(gs[0, :])  
ax_TS_tfr = fig.add_subplot(gs[1, :])  
ax_w2 = fig.add_subplot(gs[2, 0], polar=True)
ax_w3 = fig.add_subplot(gs[2, 1], polar=True)
ax_w4 = fig.add_subplot(gs[2, 2], polar=True)

legend_lines = [Line2D([0], [0], linestyle=':', color='black', label='Old'),
                Line2D([0], [0], linestyle='--', color='black', label='New')]

for band, method_pca, pc in signals :
    if band == 'broadband' :
        compo = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_bb_{method_pca}/grp_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')
        ts = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_bb_{method_pca}/grp_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0']).query('freq == @band')
        time = time_epoch 
        the_ax = ax_TS_bb

    else :
        compo = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')
        ts = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0']).query('freq == @band')
        time = time_tfr
        the_ax = ax_TS_tfr
    
    for col in ['expl_var', 'compo', 'freq', 'subj'] : 
        if col in compo.columns : 
            compo = compo.drop(columns = col)

        if col in ts.columns : 
            ts = ts.drop(columns = col)
 
    ts = ts.values
    compo = compo.values

    if band == 'alpha' :  # flip alpha
        ts_pc[:, 1, :] = - ts_pc[:, 1,:]
        compo[1, :] = - compo[1, :]

    df_data = pd.DataFrame(compo.T)
    df_abs = df_data.copy().apply(lambda x : abs(x))
    df_abs['region'] = region
    df_data['region'] = region
    df_data[[0, 1, 2, 3]] = df_data[[0, 1, 2, 3]].astype(float)
    ts_pc=np.concat([ts[None, :, :int(ts.shape[1]/2)], ts[None, :, int(ts.shape[1]/2):]], axis = 0)

    # PLOT TS
    the_ax.plot(time, ts_pc[0, pc, :].T, c= element_colors[band], ls=':', label='Old')
    the_ax.plot(time, ts_pc[1, pc, :].T, c=element_colors[band], ls='--', label='New')
    the_ax.set_xlabel('Time (s)')
    
    # PLOT WEIGHTS
    means_abs = df_abs.groupby('region').mean().loc[:, pc].reindex(COL_REG.keys()).values
    means_abs = np.concatenate([means_abs, [means_abs[0]]])
    ax_w2.plot(angles, means_abs*1000, linewidth=1, label=f"PC{pc+1}", c = element_colors[band])
    ax_w2.fill(angles, means_abs*1000, alpha=0.15, c = element_colors[band])
    ax_w2.set_title('MEAN OF |WEIGHTS|', y=1.1)

    if band != 'broadband' :
        pos_sum = df_data[df_data[pc] > 0][[pc, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).values
        neg_sum = df_data[df_data[pc] < 0][[pc, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).values
        count = df_data[[pc, 'region']].groupby('region').count().reindex(COL_REG.keys()).fillna(0).values

        pos_sum = np.concatenate([pos_sum, [pos_sum[0]]])
        neg_sum = np.concatenate([neg_sum, [neg_sum[0]]])
        count = np.concatenate([count, [count[0]]])

        ax_w3.plot(angles, pos_sum/count, linewidth=1, label=f"PC{pc}", c = element_colors[band])
        ax_w3.fill(angles, pos_sum/count, alpha=0.15, c = element_colors[band])
        ax_w3.set_title('(+) WEIGHT SUM/COUNT', y=1.1)

        ax_w4.plot(angles, -neg_sum/count, linewidth=1, label=f"PC{pc}", c = element_colors[band])
        ax_w4.fill(angles, -neg_sum/count, alpha=0.15, c = element_colors[band])
        ax_w4.set_title('(-) WEIGHT SUM/COUNT', y=1.1)
        
        ax_w3.set_ylim(0, 0.035)
        ax_w4.set_ylim(0, 0.035)

        scale = 100  # change units
        formatter = mticker.FuncFormatter(lambda x, pos: f"{x*scale:g}")
        ax_w3.yaxis.set_major_formatter(formatter)
        ax_w4.yaxis.set_major_formatter(formatter)

    for a in [ax_w2, ax_w3, ax_w4] : 
        a.set_xticks(angles[:-1])
        a.set_xticklabels(COL_REG.keys(), fontsize=8)
        a.set_theta_offset(np.pi / 2)
        a.set_theta_direction(-1)

    legend_lines.append(Line2D([0], [0], linestyle='None', marker='s', markersize=10,
           markerfacecolor=element_colors[band], markeredgecolor=element_colors[band], label=f'{band} PC{pc+1}'))
ax_TS_bb.grid()
ax_TS_tfr.grid()

ax_TS_bb.legend(handles= legend_lines, bbox_to_anchor=(0.9, -0.25), ncol=4)
ax_TS_bb.set_title(label_plt)
# Out:
# Text(0.5, 1.0, 'Memory components')

# %%
signals = [('high_gamma', 'concat', 0), ('high_gamma', 'concat', 1), ('high_gamma', 'concat', 2), ('delta', 'concat', 1), ('delta', 'concat', 0)]
label_plt = 'Different dynamics'

fig = plt.figure(figsize=(15, 5))
gs = gridspec.GridSpec(2, 2, hspace=0.6, wspace=0)
ax_TS = fig.add_subplot(gs[:, 0])  
ax_w3 = fig.add_subplot(gs[0, 1], polar=True)
ax_w4 = fig.add_subplot(gs[1, 1], polar=True)

legend_lines = [Line2D([0], [0], linestyle=':', color='black', label='Old'),
                Line2D([0], [0], linestyle='--', color='black', label='New')]

for band, method_pca, pc in signals :
    # Get data
    compo = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')
    ts = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0']).query('freq == @band')
    for col in ['expl_var', 'compo', 'freq', 'subj'] : 
        if col in compo.columns : 
            compo = compo.drop(columns = col)

        if col in ts.columns : 
            ts = ts.drop(columns = col)
 
    ts = ts.values
    compo = compo.values
    
    ts_pc=np.concat([ts[None, PCS, :int(ts.shape[1]/2)], ts[None, PCS, int(ts.shape[1]/2):]], axis = 0)

    if band == 'alpha' :  # flip alpha
        ts_pc[:, 1, :] = - ts_pc[:, 1,:]
        compo[1, :] = - compo[1, :]

    df_data = pd.DataFrame(compo.T)
    df_data['region'] = region
    df_data[[0, 1, 2, 3]] = df_data[[0, 1, 2, 3]].astype(float)

    # PLOT TS
    ax_TS.plot(time_tfr, ts_pc[0, pc, :].T, c= col_pc[pc], ls='-', label='Old')
    #ax_TS.plot(time_tfr, ts_pc[1, pc, :].T, c=element_colors[band], ls=':', label='New')
    ax_TS.set_xlabel('Time (s)')
    
    # PLOT WEIGHTS
    pos_sum = df_data[df_data[pc] > 0][[pc, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).values
    neg_sum = df_data[df_data[pc] < 0][[pc, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).values
    count = df_data[[pc, 'region']].groupby('region').count().reindex(COL_REG.keys()).fillna(0).values

    pos_sum = np.concatenate([pos_sum, [pos_sum[0]]])
    neg_sum = np.concatenate([neg_sum, [neg_sum[0]]])
    count = np.concatenate([count, [count[0]]])

    ax_w3.plot(angles, pos_sum/count, linewidth=1, label=f"PC{pc}", c = col_pc[pc])
    ax_w3.fill(angles, pos_sum/count, alpha=0.15, c = col_pc[pc])
    ax_w3.set_title('(+) WEIGHT SUM/COUNT', y=1.1)

    ax_w4.plot(angles, -neg_sum/count, linewidth=1, label=f"PC{pc}", c = col_pc[pc])
    ax_w4.fill(angles, -neg_sum/count, alpha=0.15, c = col_pc[pc])
    ax_w4.set_title('(-) WEIGHT SUM/COUNT', y=1.1)
    
    ax_w3.set_ylim(0, 0.035)
    ax_w4.set_ylim(0, 0.035)

    scale = 100  # change units
    formatter = mticker.FuncFormatter(lambda x, pos: f"{x*scale:g}")
    ax_w3.yaxis.set_major_formatter(formatter)
    ax_w4.yaxis.set_major_formatter(formatter)

    for a in [ax_w3, ax_w4] : 
        a.set_xticks(angles[:-1])
        a.set_xticklabels(COL_REG.keys(), fontsize=8)
        a.set_theta_offset(np.pi / 2)
        a.set_theta_direction(-1)

    legend_lines.append(Line2D([0], [0], linestyle='None', marker='s', markersize=10,
           markerfacecolor=element_colors[band], markeredgecolor=element_colors[band], label=f'{band} PC{pc+1}'))
ax_TS.grid()
ax_TS.set_title(f'PCs {label_plt}')

ax_TS.legend(handles= legend_lines, bbox_to_anchor=(1.01, -0.1), ncol=2)

# %%
from nilearn import plotting

# %%
signals = [('high_gamma', 'concat', 0), ('theta', 'concat', 1)]
models = {
    'delta0': ('duplicat', 'LR'), 'delta1':('duplicat', 'SVC_linear'), "delta2" : ('mean', 'LR'),
    'theta0': ('duplicat', 'RandomForest'), 'theta1':('duplicat', 'RandomForest'), "theta2" : ('mean', 'LR'),
    'alpha0': ('mean', 'LR'), 'alpha1':( 'mean', 'LR'), "alpha2" : ( 'mean', 'RandomForest'),
    'low_beta0': ('mean', 'LR'), 'low_beta1':( 'mean', 'LR'), "low_beta2" : ( 'mean', 'LR'),
    'high_beta0': ('mean', 'LR'), 'high_beta1':( 'duplicat', 'LR'), "high_beta2" : ( 'mean', 'LR'),
    'high_gamma0': ('duplicat', 'RandomForest'), 'high_gamma1':(None, None), "high_gamma2" : ( 'duplicat', 'RandomForest') }

fig = plt.figure(figsize=(8, 10))
gs = gridspec.GridSpec(3, 1, hspace=0.5)
ax_TS_1 = fig.add_subplot(gs[1, 0])  
ax_topo2 = fig.add_subplot(gs[2, 0])
ax_topo1 = fig.add_subplot(gs[0, 0])
topo_ax = [ax_topo1, ax_topo2]
ts_ax = [ax_TS_1,  ax_TS_1]
label_plot = []


cmap_pos = LinearSegmentedColormap.from_list(
    "pc1_orange",
    ["#FFFFFF", "#D83B29"]
)
cmap_neg = LinearSegmentedColormap.from_list(
    "pc1_orange",
    ["#D6E0F6", "#3B7EEA"]
)
import matplotlib.colors as mcolors

for i, (band, method_pca, pc) in enumerate(signals) :
    compo = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')
    ts = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0']).query('freq == @band')
    for col in ['expl_var', 'compo', 'freq', 'subj'] : 
        if col in compo.columns : 
            compo = compo.drop(columns = col)

        if col in ts.columns : 
            ts = ts.drop(columns = col)
    
    ts = ts.values
    compo = compo.values    

    if band == 'alpha' :  # flip alpha
        ts[1, :] = - ts[1,:]
        compo[1, :] = - compo[1, :]

    ts_pc=np.concat([ts[None, pc, :int(ts.shape[1]/2)], ts[None, pc, int(ts.shape[1]/2):]], axis = 0)

    y = np.asarray(ts_pc[0, :])
    pos = y >= 0
    neg = y < 0
    ax_TS_1.plot(time_tfr, np.ma.masked_where(~pos, y),
            color="#d62728", linestyle=':', linewidth=1)
    ax_TS_1.plot(time_tfr, np.ma.masked_where(~neg, y),
            color="#1f77b4", linestyle=':', linewidth=1)
    
    y = np.asarray(ts_pc[1, :])
    pos = y >= 0
    neg = y < 0
    ax_TS_1.plot(time_tfr, np.ma.masked_where(~pos, y),
            color="#d62728", linestyle='--', linewidth=1)
    ax_TS_1.plot(time_tfr, np.ma.masked_where(~neg, y),
            color="#1f77b4", linestyle='--', linewidth=1)

    ax_TS_1.set_xlabel('Time (s)')
    
    #index_thr = np.where(compo_thr.T[:, pc] != 0)[0]
    #compo_thr = CompoThr(compo)[pc, :]
    max_act = 0.15 #np.max(abs(compo[pc, :]))
    min_act = -max_act

    index_thr = np.where(abs(compo[pc, :]) > (np.mean(compo[pc, :]) + np.std(compo[pc, :])))[0]
    n_nodes = len(coord)
    node_sizes = np.full(n_nodes, 0)        
    node_sizes[index_thr] = 9    

    fig = plotting.plot_markers(node_coords = np.array(coord),  
                                node_size=node_sizes, 
                                node_values=compo[pc, :],
                                node_cmap='seismic',
                                display_mode='ortho', 
                                node_vmin=min_act, 
                                node_vmax=max_act, 
                                axes = topo_ax[i])
    topo_ax[i].set_title(band.capitalize().replace('_', ' ') + ' : PC ' + str(pc+1))

    # add the model coeff
    data_aug_method = models[band + str(pc)][0]
    model = models[band + str(pc)][1]
    
    if model == None :
        continue
    df_final = pd.read_csv(OUT_PATH + f'/Decoding_shuffled_trials/{band}/fullmodel/{method_pca}_{data_aug_method}_{pc}_{model}full.csv')
    result = cleandfdecodingTS(df_final, len(time_tfr))
    
    if result['acc'] < 0.7 :
        label_text = f'{band.capitalize().replace('_', ' ')} : PC {str(pc+1)} \n {model.replace("_", " ")} (acc: {np.round(result["acc"], 2)}), aug:{data_aug_method}'
    else : 
        label_text = f'{band.capitalize().replace('_', ' ')} : PC {str(pc+1)} \n {model.replace("_", " ")} (acc: {np.round(result["acc"], 2)}), aug:{data_aug_method}'
    
    weight_mean= abs(result['weight_mean'])
    weight_sh_mean= abs(result['weight_sh_mean'])
    weight_sh_std= abs(result['weight_sh_std'])
    weight_prop = weight_mean/(weight_sh_mean+weight_sh_std)
    weight_mean_norm = (weight_prop - weight_prop.min()) / (weight_prop.max() - weight_prop.min())


    for it in range(len(time_tfr) - 1):

        y1 = ts_pc[0, it:it+2]
        y2 = ts_pc[1, it:it+2]
        y_mean = np.mean([y1.mean(), y2.mean()])  # polarity reference

        color_strength = weight_mean_norm[it]

        if y_mean >= 0:
            color = cmap_pos(color_strength)
        else:
            color = cmap_neg(color_strength)

        ts_ax[i].fill_between(
            time_tfr[it:it+2],
            y1,
            y2,
            color=color,
            linewidth=0
        )
    x_pt = time_tfr[100]
    y_pt = np.mean([ts_pc[0, 100], ts_pc[1, 100]])

    ax_TS_1.annotate(
    label_text,
    xy=(x_pt, y_pt),                 # arrow target on curve
    xytext=(x_pt + 0.3 + (i-1)*(-0.5), y_pt + 0.5+ 0.2*(i+1)),  # stagger labels
    arrowprops=dict(arrowstyle="->", lw=1),
    bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="black", alpha=0.9),
    fontsize=9)

legend_lines = [Line2D([0], [0], linestyle=':', color='black', label='Old'),
                Line2D([0], [0], linestyle='--', color='black', label='New'), 
                Line2D([0], [0], linestyle='None', marker='s', markersize=10,
           markerfacecolor='b', markeredgecolor='b', label=f'Negative Contribution'), 
           Line2D([0], [0], linestyle='None', marker='s', markersize=10,
           markerfacecolor='r', markeredgecolor='r', label=f'Positive Contribution')]


ax_TS_1.grid()
ax_TS_1.legend(handles=legend_lines, bbox_to_anchor=(0.5, 1.2), ncol=6, loc='upper center',)
plt.show()

# %% [markdown]
# # Moving plot

# %%
data_grp = get_data_grp(subj_included, type_data='tfr', data_path=tfr_path)

# %%
# plot topo pc1, ts, pc2 for each tp
data_aug_method = 'mean'
method_pca = 'concat'
band = 'high_gamma'
model_name = 'LR'
time = time_tfr
data = data_grp[:, :, FREQ_BAND.index(band),:]
compo = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')
ts = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0']).query('freq == @band')
for col in ['expl_var', 'compo', 'freq', 'subj'] : 
    if col in compo.columns : 
        compo = compo.drop(columns = col)

    if col in ts.columns : 
        ts = ts.drop(columns = col)

ts = ts.values
compo = compo.values
ts_pc=np.concat([ts[None, PCS, :int(ts.shape[1]/2)], ts[None, PCS, int(ts.shape[1]/2):]], axis = 0)

for tp in [0, 50, 100] : 
    fig = plt.figure(figsize=(12, 8))
    gs = gridspec.GridSpec(2, 4, height_ratios=[3/5, 2/5], hspace=0.5, wspace=0.3)
    ax_TS = fig.add_subplot(gs[0, :])  
    ax_w1 = fig.add_subplot(gs[1, 0], polar=True)
    ax_w2 = fig.add_subplot(gs[1, 1], polar=True)
    ax_w3 = fig.add_subplot(gs[1, 2], polar=True)
    ax_w4 = fig.add_subplot(gs[1, 3], polar=True)

    # Weights of the decoding model as a gradiant
    from utils import cleandfdecodingTS
    weightLR = []
    for pc_use in PCS : 
        df_final = pd.read_csv(OUT_PATH + f'/Decoding/{band}/fullmodel/{method_pca}_{data_aug_method}_{pc_use}_{model_name}full.csv')
        result = cleandfdecodingTS(df_final, len(time))
        weight_mean= abs(result['weight_mean'])
        weight_sh_mean= abs(result['weight_sh_mean'])
        weight_sh_std= result['weight_sh_std']
        weight_prop = weight_mean/(weight_sh_mean+weight_sh_std)
        weightLR.append(weight_prop)

    for i in range(len(time) - 1):
        for pc in PCS : 
            ax_TS.fill_between(time[i:i+2],ts_pc[0, pc, i:i+2],ts_pc[1, pc, i:i+2],color=cmap_pcs[pc](weightLR[pc][i]),linewidth=0)
    
    for pc_use in PCS : 
        ax_TS.plot(time, ts_pc[0, pc_use, :].T, c=col_pc[pc_use], ls=':', linewidth = 1)
        ax_TS.plot(time, ts_pc[1, pc_use, :].T, c=col_pc[pc_use], ls='--', linewidth = 1)
        
    ax_TS.grid()
    ax_TS.set_xlabel('Time (s)')
    ax_TS.set_title('PCs TIME SERIES')
    ax_TS.legend( bbox_to_anchor=(1, -0.1), ncol=2)

    ax_TS.scatter([time[tp], time[tp], time[tp]], ts_pc[0, :, tp].T, s=50, marker='.', c=['b', 'b', 'b'], label = 'Old')
    ax_TS.scatter([time[tp], time[tp], time[tp]], ts_pc[1, :, tp].T, s=50, marker='.', c=['r', 'r', 'r'], label = 'New')

    n_regions = len(COL_REG.keys())
    angles = np.linspace(0, 2 * np.pi, n_regions, endpoint=False)
    angles = np.concatenate([angles, [angles[0]]])

    # pos and neg sum /count 
    for PC_use in PCS : 
        act= data.mean(0)[:, tp] * compo[PC_use, :][:, None]
        
        df_act = pd.DataFrame(act)
        df_abs = df_act.copy().apply(lambda x : abs(x))
        df_act['region'] = region
        df_abs['region'] = region
        # mean of the absolute value --> wher is the main contribution
        means_abs = df_abs.groupby('region').mean().loc[:, PC_use].reindex(COL_REG.keys()).values
        means_abs = np.concatenate([means_abs, [means_abs[0]]])
        ax_w1.plot(angles, means_abs*1000, linewidth=1, label=f"PC{PC_use+1}", c = col_pc[PC_use])
        ax_w1.fill(angles, means_abs*1000, alpha=0.15, c = col_pc[PC_use])
        ax_w1.set_title('MEAN OF |WEIGHTS|', y=1.1)

        # largest 
        index_largest = df_abs.nlargest(100, columns = PC_use).index
        largest = df_act.loc[index_largest, :].groupby('region').count().loc[:, PC_use]
        largest = largest.reset_index()
        for reg in df_act['region'] : 
            if reg not in largest['region'].values :
                largest = pd.concat([largest, pd.DataFrame([[reg, 0]], columns = ['region', PC_use])])
        largest = largest.set_index('region').reindex(COL_REG.keys()).values
        largest = np.concatenate([largest, [largest[0]]])
        ax_w2.plot(angles, largest, linewidth=1, label=f"PC{PC_use}", c = col_pc[PC_use])
        ax_w2.fill(angles, largest, alpha=0.15, c = col_pc[PC_use])
        ax_w2.set_title('LARGEST |WEIGHTS| COUNT', y=1.1)

        pos_sum = df_act[df_act[PC_use] > 0][[PC_use, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).values
        neg_sum = df_act[df_act[PC_use] < 0][[PC_use, 'region']].groupby('region').sum().reindex(COL_REG.keys()).fillna(0).values
        count = df_act[[PC_use, 'region']].groupby('region').count().reindex(COL_REG.keys()).fillna(0).values

        pos_sum = np.concatenate([pos_sum, [pos_sum[0]]])
        neg_sum = np.concatenate([neg_sum, [neg_sum[0]]])
        count = np.concatenate([count, [count[0]]])

        ax_w3.plot(angles, pos_sum/count, linewidth=1, label=f"PC{PC_use}", c = col_pc[PC_use])
        ax_w3.fill(angles, pos_sum/count, alpha=0.15, c = col_pc[PC_use])
        ax_w3.set_title('(+) WEIGHT SUM/COUNT', y=1.1)

        ax_w4.plot(angles, -neg_sum/count, linewidth=1, label=f"PC{PC_use}", c = col_pc[PC_use],)
        ax_w4.fill(angles, -neg_sum/count, alpha=0.15, c = col_pc[PC_use])
        ax_w4.set_title('(-) WEIGHT SUM/COUNT', y=1.1)
        
        scale = 1000  # change to 1e6 if you want micro-units etc.
        formatter = mticker.FuncFormatter(lambda x, pos: f"{x*scale:g}")
        ax_w3.yaxis.set_major_formatter(formatter)
        ax_w4.yaxis.set_major_formatter(formatter)

    for a in [ax_w1, ax_w2, ax_w3, ax_w4] : 
        a.set_xticks(angles[:-1])
        a.set_xticklabels(COL_REG.keys(), fontsize=8)
        a.set_theta_offset(np.pi / 2)
        a.set_theta_direction(-1)

    ax_w1.set_ylim(0, 5)
    ax_w2.set_ylim(0, 50)
    ax_w3.set_ylim(0, 0.004)
    ax_w4.set_ylim(0, 0.004)


    ax_w1.legend(
            loc='upper left',
            bbox_to_anchor=(-0.1, 1.5), ncol  =3)
    
    fig.savefig(OUT_PATH + f'/final/{band}/gg_plot_{tp}.png')
    plt.close()
# Out:
# /var/folders/rr/sx7rgrrj3p12hz70crvxqcjc0000gn/T/ipykernel_2344/1745530396.py:39: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_TS.legend( bbox_to_anchor=(1, -0.1), ncol=2)
# /var/folders/rr/sx7rgrrj3p12hz70crvxqcjc0000gn/T/ipykernel_2344/1745530396.py:39: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_TS.legend( bbox_to_anchor=(1, -0.1), ncol=2)
# /var/folders/rr/sx7rgrrj3p12hz70crvxqcjc0000gn/T/ipykernel_2344/1745530396.py:39: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_TS.legend( bbox_to_anchor=(1, -0.1), ncol=2)

# %%
from nilearn import plotting

# %%
# per pc with topomap
data_aug_method = 'mean'
method_pca = 'concat'
band = 'high_gamma'
time = time_tfr
data = data_grp[:, :, FREQ_BAND.index(band),:]

compo = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Compo_PCA5.csv').drop(columns = 'Unnamed: 0').query('freq == @band')
ts = pd.read_csv(OUT_PATH + f'/grpPCA/supsubj_{method_pca}/grp_{method_pca}_Xtrans_PCA5.csv').drop(columns = ['Unnamed: 0']).query('freq == @band')
for col in ['expl_var', 'compo', 'freq', 'subj'] : 
    if col in compo.columns : 
        compo = compo.drop(columns = col)

    if col in ts.columns : 
        ts = ts.drop(columns = col)

ts = ts.values
compo = compo.values
ts_pc=np.concat([ts[None, :, :int(ts.shape[1]/2)], ts[None, :, int(ts.shape[1]/2):]], axis = 0)

# %%
for pc in [0, 1, 2]:  
  act= data.mean(0) * compo[pc, :][:, None]
  max_act = np.max(abs(act))
  min_act =-max_act
  thr= max_act*0.05

  for tp in range(3) : #len(time_tfr)) : 
      fig = plt.figure(figsize=(12, 8))
      gs = gridspec.GridSpec(2, 1, height_ratios=[3/5, 2/5], hspace=0.5, wspace=0.3)
      ax_TS = fig.add_subplot(gs[0, 0])  
      ax_topo = fig.add_subplot(gs[1, 0])
      
      ax_TS.plot(time, ts_pc[0, pc, :].T, c=col_pc[pc], ls=':', linewidth = 1, label='Old')
      ax_TS.plot(time, ts_pc[1, pc, :].T, c=col_pc[pc], ls='--', linewidth = 1, label = 'New')
      ax_TS.grid()
      ax_TS.set_xlabel('Time (s)')
      ax_TS.set_title(f'PC {pc+1}')
      ax_TS.legend( bbox_to_anchor=(1, -0.1), ncol=2)

      ax_TS.scatter([time[tp]], ts_pc[0, pc, tp].T, s=20, marker='o', c=['k'], label = 'Old')
      ax_TS.scatter([time[tp]], ts_pc[1, pc, tp].T, s=20, marker='x', c=['k'], label = 'New')
      ax_TS.legend()
      #index_thr = np.where(compo_thr.T[:, pc] != 0)[0]
      index_thr = np.where(abs(act[:, tp]) > thr)[0]
      n_nodes = len(coord)
      node_sizes = np.full(n_nodes, 0)        
      node_sizes[index_thr] = 20    

      fig = plotting.plot_markers(node_coords = np.array(coord),  
                                  node_size=node_sizes, 
                                  node_values=act[:, tp],
                                  node_cmap='seismic',
                                    display_mode='ortho', 
                                    node_vmin=min_act, 
                                    node_vmax=max_act, 
                                    axes = ax_topo)


      #fig.savefig(OUT_PATH + f'/final/{band}/{pc}_topo_gg_plot_{tp}.png')
      #plt.close()
